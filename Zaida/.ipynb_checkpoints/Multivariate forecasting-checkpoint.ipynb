# %%
import pandas as pd

# %%
df = pd.read_csv('country_info.csv')

# %%
df
# Out:
#     Unnamed: 0           Timestamp          country start_date  \
# 0            0  4/10/2020 14:03:47          Belgium  3/18/2020
# 1            1  4/15/2020 12:15:09          Croatia  3/18/2020
# 2            2   4/24/2020 8:17:43          Denmark  3/11/2020
# 3            3  4/10/2020 14:02:19           France  3/16/2020
# 4            4  4/15/2020 12:02:17          Germany  3/20/2020
# 5            5  4/10/2020 12:24:15          Ireland  3/24/2020
# 6            6  4/10/2020 20:23:04           Israel   4/2/2020
# 7            7  4/10/2020 14:02:19            Italy  3/10/2020
# 8            8  4/25/2020 15:36:01            Japan   4/7/2020
# 9            9  4/10/2020 12:36:01   United Kingdom  3/23/2020
# 10          10  4/10/2020 10:54:06      Netherlands  3/23/2020
# 11          11   4/24/2020 7:53:23  North Macedonia  3/19/2020
# 12          12  4/10/2020 12:46:22         Slovenia  3/16/2020
# 13          13  4/10/2020 12:03:11      Switzerland  3/17/2020
# ...

# %% [markdown]
# # Preprocessing

# %% [markdown]
# #### Nans

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Timestamp       0
# country         0
# start_date      0
# end_date       13
#                ..
# sept_temp       0
# oct_temp        0
# nov_temp        0
# dec_temp        0
# annual_temp     0
# Length: 61, dtype: int64

# %%
df = df.drop(['end_date'],axis=1)

# %% [markdown]
# ##### Fil Maximum_together column

# %%
df['maximum_together'] = df['maximum_together'].fillna(10)
# Out:
# 0      2.0
# 1     10.0
# 2     10.0
# 3      2.0
# 4      2.0
# 5      3.0
# 6      4.0
# 7      1.0
# 8     10.0
# 9      2.0
# 10     3.0
# 11     2.0
# 12     2.0
# 13     5.0
# 14     2.0
# Name: maximum_together, dtype: float64

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['maximum_together',
#  'hosp_beds_per_1000_2017',
#  'ICU-CCB_beds_per_100000',
#  'sex_male_to_female_total',
#  'first_school_closure_date',
#  'airport_traffic_2018_thousands']

# %%
df['maximum_together']
# Out:
# 0      2.0
# 1      NaN
# 2     10.0
# 3      2.0
# 4      2.0
# 5      3.0
# 6      4.0
# 7      1.0
# 8      NaN
# 9      2.0
# 10     3.0
# 11     2.0
# 12     2.0
# 13     5.0
# 14     2.0
# Name: maximum_together, dtype: float64
