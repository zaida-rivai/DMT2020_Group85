# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Corrected_df.csv")

df.Date = pd.to_datetime(df.Date)
df = df.sort_values(by=['Date'])
df = df.set_index(df.Date)
df['Month'] = df['Date'].map(lambda x: 100*x.month)
df = df.drop(['Date'],axis=1)
Belgium = df[df['Country/Region']==0.0]

# %%
# Belgium.head()
Belgium.columns
# Out:
# Index(['Deaths', 'Confirmed', 'Recovered', 'Country/Region', 'Date.1',
#        'start_date', 'lockdown_severity', 'leasure_shopping_prohibited',
#        'maximum_together', 'mentality_grade', 'government_performance',
#        'kindergarten_open_to_vital', 'highschool_open_to_vital',
#        'university_open_to_vital', 'going_out_for_dinner_prohibited_all',
#        'leaving_the_house_for_no_reason_prohibited_all',
#        'public_transportation_prohibited_all', 'sports_games_prohibited_all',
#        'hospital_open_to_vital', 'none_open_to_vital', 'none__open_to_vital',
#        'bars_closed_to_everyone', 'highschool_closed_to_everyone',
#        'kindergarten_closed_to_everyone', 'restaurants_closed_to_everyone',
#        'shops_other_than_supermarkets_closed_to_everyone',
#        'protection_Not at all', 'protection_Only for any healthcare worker',
#        'protection_Only for hospital staff',
#        'protection_Sufficient for everyone', 'covid19_first_date',
# ...

# %% [markdown]
# ##### Check if dataframe is correctly sorted now

# %%
plt.plot(Belgium.Deaths)

# %% [markdown]
# ##### Separate label columns

# %%
labels = Belgium.iloc[:,4:]
target = Belgium.iloc[:,1]

# %%
labels
# Out:
#      Country/Region        Date.1  start_date  lockdown_severity  \
# 0               0.0  1.579651e+18         5.0                5.0
# 1               0.0  1.579738e+18         5.0                5.0
# 2               0.0  1.579824e+18         5.0                5.0
# 3               0.0  1.579910e+18         5.0                5.0
# 4               0.0  1.579997e+18         5.0                5.0
# ..              ...           ...         ...                ...
# 102             0.0  1.588464e+18         5.0                5.0
# 103             0.0  1.588550e+18         5.0                5.0
# 104             0.0  1.588637e+18         5.0                5.0
# 105             0.0  1.588723e+18         5.0                5.0
# 106             0.0  1.588810e+18         5.0                5.0
#
#      leasure_shopping_prohibited  maximum_together  mentality_grade  \
# 0                            1.0               2.0              7.0
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
import matplotlib.pyplot as plt

# %%
plt.plot(target)

# %%
model = VAR(labels)
model_fit = model.fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-df5029cd7993> in <module>
#       1 model = VAR(labels)
# ----> 2 model_fit = model.fit()
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in fit(self, maxlags, method, ic, trend, verbose)
#     644         self.data.cov_names = pd.MultiIndex.from_product((self.data.xnames,
#     645                                                           self.data.ynames))
# --> 646         return self._estimate_var(lags, trend=trend)
#     647
#     648     def _estimate_var(self, lags, offset=0, trend='c'):
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in _estimate_var(self, lags, offset, trend)
#     666         exog = None if self.exog is None else self.exog[offset:]
#     667         z = util.get_var_endog(endog, lags, trend=trend,
# ...
